# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya-carpediem08/AI-Ml2023/blob/main/ISOC_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import string
import os
import tensorflow as tf
from PIL import Image
from tqdm import tqdm
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.models import Model
from keras.layers import Input, Dense, Embedding, LSTM, add
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import warnings

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/content/drive/MyDrive'
# !kaggle datasets download -d adityajn105/flickr8k
# Out:
# Downloading flickr8k.zip to /content
# 100% 1.03G/1.04G [00:28<00:00, 44.4MB/s]
# 100% 1.04G/1.04G [00:28<00:00, 39.2MB/s]

# %% [markdown]
# the following code is generating an error because I cancelled the operation midway as the file was already downloaded and mounted in my drive

# %%
import zipfile

# Specify the path to the uploaded ZIP file
zip_file_path = "/content/flickr8k.zip"  # Update this with the actual path

# Specify the directory where you want to extract the contents of the ZIP file
extract_to_directory = "/content/drive/MyDrive"  # Update this with the desired extraction path

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_directory)

# Check the extracted files
extracted_files = zip_ref.namelist()  # List of extracted files
print("Extracted files:", extracted_files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-91b07053ea2f> in <cell line: 10>()
#       8
#       9 # Unzip the file
# ---> 10 with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#      11     zip_ref.extractall(extract_to_directory)
#      12
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/flickr8k.zip'

# %% [markdown]
# #Pre-processing the images
# Including the Inception V3 model , which converts the images into feature vectors and also including exception handling for images which have unsupported image formats.

# %%
# making a function for loading the image and pre-processing the image

def load_image_features(directory):
    model = InceptionV3(weights='imagenet')
    model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
    features = {}
    for img_name in tqdm(os.listdir(directory)):
        filename = os.path.join(directory, img_name)
        try:
            image = Image.open(filename)
            image = image.resize((299, 299))
            image = np.expand_dims(image, axis=0)
            image = preprocess_input(image)
            feature = model.predict(image, verbose=0)
            image_id = img_name.split('.')[0]
            features[image_id] = feature
        except (OSError, PIL.UnidentifiedImageError) as e:
            warnings.warn(f"Error processing {filename}: {e}")
            continue  # Skip to the next image
    return features

# %% [markdown]
# Pre-Processing the captions

# %%
def preprocess_captions(captions):
    table = str.maketrans('', '', string.punctuation)
    for img_id, caption_list in captions.items():
        for i in range(len(caption_list)):
            caption = caption_list[i].split()
            caption = [word.lower() for word in caption]
            caption = [w.translate(table) for w in caption]
            caption = [word for word in caption if len(word) > 1]
            caption = [word for word in caption if word.isalpha()]
            caption_list[i] = ' '.join(caption)
    return captions

# %%
# Creating tokens for the captions
def create_tokenizer(captions):
    captions_list = list(captions.values())
    all_captions = []
    for caption_list in captions_list:
        all_captions += caption_list
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(all_captions)
    return tokenizer

# %% [markdown]
# *Since the datapoints in the caption file is of the format (image_name.jpg,caption), it is necessary to separate the captions and the image_name.*

# %%
def load_annotations(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    image_captions = {}
    for line in lines:
        parts = line.strip().split(',')
        if len(parts) == 2:  # Ensuring the line has both image name and caption
            image_name = parts[0].strip()
            caption = parts[1].strip()
            if image_name not in image_captions:
                image_captions[image_name] = []
            image_captions[image_name].append(caption)

    return image_captions

# %%
# Create sequences of images, input sequences, and output words for training the model
def create_sequences(tokenizer, captions, image_features, vocab_size, max_length):
    X1, X2, y = [], [], []
    for img_id, caption_list in captions.items():
        image_feature = image_features[img_id][0]
        for caption in caption_list:
            seq = tokenizer.texts_to_sequences([caption])[0]
            for i in range(1, len(seq)):
                in_seq, out_seq = seq[:i], seq[i]
                in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                X1.append(image_feature)
                X2.append(in_seq)
                y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

# %%
# Define the image captioning model
def define_model(vocab_size, max_length):
    input1 = Input(shape=(2048,))
    fe1 = Dense(256, activation='relu')(input1)
    input2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, 256, mask_zero=True)(input2)
    se2 = LSTM(256)(se1)
    decoder1 = add([fe1, se2])
    decoder2 = Dense(256, activation='relu')(decoder1)
    output = Dense(vocab_size, activation='softmax')(decoder2)
    model = Model(inputs=[input1, input2], outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    return model

# %%
# Load Flickr 8k dataset annotations
annotations_path = '/content/drive/MyDrive/captions.txt'
captions = load_annotations(annotations_path)
captions = preprocess_captions(captions)
captions
# Out:
# {'image': ['caption'],
#  '1000268201_693b08cb0e.jpg': ['child in pink dress is climbing up set of stairs in an entry way',
#   'girl going into wooden building',
#   'little girl climbing into wooden playhouse',
#   'little girl climbing the stairs to her playhouse',
#   'little girl in pink dress going into wooden cabin'],
#  '1001773457_577c3a7d70.jpg': ['black dog and spotted dog are fighting',
#   'black dog and tricolored dog playing with each other on the road',
#   'black dog and white dog with brown spots are staring at each other in the street',
#   'two dogs of different breeds looking at each other on the road',
#   'two dogs on pavement moving toward each other'],
#  '1002674143_1b742ab4b8.jpg': ['little girl covered in paint sits in front of painted rainbow with her hands in bowl',
#   'little girl is sitting in front of large painted rainbow',
#   'small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it',
#   'there is girl with pigtails sitting in front of rainbow painting',
#   'young girl with pigtails painting outside in the grass'],
#  '1003163366_44323f5815.jpg': ['man lays on bench while his dog sits by him',
#   'man lays on the bench to which white dog is also tied',
#   'man sleeping on bench outside with white and black dog sitting next to him',
#   'shirtless man lies on park bench with his dog',
#   'man laying on bench holding leash of dog sitting on ground'],
#  '1007129816_e794419615.jpg': ['man in an orange hat starring at something',
#   'man wears an orange hat and glasses',
#   'man with gauges and glasses is wearing blitz hat',
#   'man with glasses is wearing beer can crocheted hat',
#   'the man with pierced ears is wearing glasses and an orange hat'],
#  '1007320043_627395c3d8.jpg': ['child playing on rope net',
#   'little girl climbing on red roping',
#   'little girl in pink climbs rope bridge at the park',
#   'small child grips onto the red ropes at the playground',
#   'the small child climbs on red ropes on playground'],
#  '1009434119_febe49276a.jpg': ['black and white dog is running in grassy garden surrounded by white fence',
#   'black and white dog is running through the grass',
#   'boston terrier is running in the grass',
#   'boston terrier is running on lush green grass in front of white fence',
#   'dog runs on the green grass near wooden fence'],
#  '1012212859_01547e3f17.jpg': ['white dog shakes on the edge of beach with an orange ball',
#   'white dog playing with red ball on the shore near the water',
#   'white dog with brown ears standing near water with head turned to one side'],
#  '1015118661_980735411b.jpg': ['boy smiles in front of stony wall in city',
#   'little boy is standing on the street while man in overalls is working on stone wall',
#   'young boy runs aross the street',
#   'young child is walking on stone paved street with metal pole and man behind him',
#   'smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him'],
#  '1015584366_dfcec3c85a.jpg': ['black dog leaps over log',
#   'grey dog is leaping over fallen tree',
#   'large black dog leaps fallen log',
#   'mottled black and grey dog in blue collar jumping over fallen tree',
#   'the black dog jumped the tree stump'],
#  '101654506_8eb26cfb60.jpg': ['brown and white dog is running through the snow',
#   'dog is running in the snow',
#   'dog running through snow',
#   'white and brown dog is running through snow covered field',
#   'the white and brown dog is running over the surface of the snow'],
#  '101669240_b2d3e7f17b.jpg': ['man in hat is displaying pictures next to skier in blue hat',
#   'man skis past another man displaying paintings in the snow',
#   'person wearing skis looking at framed pictures set up in the snow',
#   'skier looks at framed pictures in the snow next to trees',
#   'man on skis looking at artwork for sale in the snow'],
#  '1016887272_03199f49c4.jpg': ['collage of one person climbing cliff',
#   'group of people are rock climbing on rock climbing wall',
#   'group of people climbing rock while one man belays',
#   'seven climbers are ascending rock face whilst another man stands holding the rope',
#   'several climbers in row are climbing the rock while the man in red watches and holds the line'],
#  '1019077836_6fc9b15408.jpg': ['brown dog chases the water from sprinkler on lawn',
#   'brown dog plays with the hose',
#   'brown dog running on lawn near garden hose',
#   'dog is playing with hose',
#   'large brown dog running away from the sprinkler in the grass'],
#  '1019604187_d087bf9a5f.jpg': ['dog prepares to catch thrown object in field with nearby cars',
#   'white dog is about to catch yellow ball in its mouth',
#   'white dog is about to catch yellow dog toy',
#   'white dog is ready to catch yellow ball flying through the air',
#   'white dog running after yellow ball'],
#  '1020651753_06077ec457.jpg': ['black and white dog jumping in the air to get toy',
#   'black and white dog jumps up towards yellow toy',
#   'dog leaps to catch ball in field',
#   'white dog is trying to catch ball in midair over grassy field',
#   'the white dog is playing in green field with yellow toy'],
#  '1022454332_6af2c1449a.jpg': ['child and woman are at waters edge in big city',
#   'large lake with lone duck swimming in it with several people around the edge of it',
#   'little boy at lake watching duck',
#   'young boy waves his hand at the duck in the water surrounded by green park'],
#  '1022454428_b6b660a67b.jpg': ['couple sit on the grass with baby and stroller',
#   'couple with their newborn baby sitting under tree facing lake',
#   'man and woman care for an infant along the side of body of water',
#   'couple with baby sit outdoors next to their stroller'],
#  '1022975728_75515238d8.jpg': ['black dog running in the surf',
#   'black lab with tags frolicks in the water',
#   'dog splashes in the water',
#   'the black dog runs through the water',
#   'this is black dog splashing in the water'],
#  '102351840_323e3de834.jpg': ['man drilling hole in the ice',
#   'man is drilling through the frozen ice of pond',
#   'person in the snow drilling hole in the ice',
#   'person standing on frozen lake',
#   'two men are ice fishing'],
#  '1024138940_f1fefbdce1.jpg': ['two different breeds of brown and white dogs play on the beach',
#   'two dogs are making turn on soft sand beach',
#   'two dogs playing in the sand at the beach',
#   'two dogs playing together on beach',
#   'two large tan dogs play along sandy beach'],
#  '102455176_5f8ead62d5.jpg': ['man uses ice picks and crampons to scale ice',
#   'an ice climber in blue jacket and black pants is scaling frozen ice wall',
#   'an ice climber scaling frozen waterfall',
#   'person in blue and red ice climbing with two picks',
#   'climber climbing an ice wall'],
#  '1026685415_0431cbf574.jpg': ['black dog carries green toy in his mouth as he walks through the grass',
#   'black dog carrying something through the grass',
#   'black dog has blue toy in its mouth',
#   'dog in grass with blue item in his mouth',
#   'wet black dog is carrying green toy through the grass'],
#  '1028205764_7e8df9a2ea.jpg': ['man and baby are in yellow kayak on water',
#   'man and little boy in blue life jackets are rowing yellow canoe',
#   'man and child kayak through gentle waters',
#   'man and young boy ride in yellow kayak',
#   'man and child in yellow kayak'],
#  '1030985833_b0902ea560.jpg': ['black dog and brown dog are jumping up to catch red toy',
#   'black dog and brown dog play with red toy on courtyard',
#   'brown and black lab are outside and the black lab is catching toy in its mouth',
#   'black dog snaps at red and black object as brown dog lunges',
#   'the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway'],
#  '103106960_e8a41d64f8.jpg': ['boy with stick kneeling in front of goalie net',
#   'child in red jacket playing street hockey guarding goal',
#   'young kid playing the goalie in hockey rink',
#   'young male kneeling in front of hockey goal with hockey stick in his right hand'],
#  '103195344_5d2dc613a3.jpg': ['man in black is sitting next to modern art structure in front of glass building',
#   'man sits and reads newspaper by sculpture outside of an office building',
#   'man sits near large statue',
#   'man sitting in front of metal sculpture in front of building',
#   'the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading'],
#  '103205630_682ca7285b.jpg': ['tent is being set up on the ice',
#   'two men are about to enter an ice fishing tent on snow covered lake',
#   'two men setting up blue ice fishing hut on an iced over lake',
#   'two people standing outside blue tent structure on snowy surface'],
#  '1032122270_ea6f0beedb.jpg': ['woman crouches near three dogs in field',
#   'three dogs are playing on grassy hill with blue sky',
#   'three dogs are standing in the grass and person is sitting next to them',
#   'three dogs on grassy hill',
#   'three dogs stand in grassy field while person kneels nearby'],
#  '1032460886_4a598ed535.jpg': ['man is standing in front of skyscraper',
#   'man stands in front of skyscraper',
#   'man stands in front of very tall building',
#   'behind the man in red shirt stands large skyscraper',
#   'there is skyscraper in the distance with man walking in front of the camera'],
#  '1034276567_49bb87c51c.jpg': ['boy bites hard into treat while he sits outside',
#   'child biting into baked good',
#   'small boy putting something in his mouth with both hands',
#   'the boy eats his food outside at the table',
#   'the boy is eating pizza over tin dish'],
#  '104136873_5b5d41be75.jpg': ['people sit on the mountainside and check out the view',
#   'three people are on hilltop overlooking green valley',
#   'three people hang out on top of big hill',
#   'three people overlook green valley',
#   'three people rest on ledge above the moutains'],
#  '1042020065_fb3d3ba5ba.jpg': ['boy in green shirt is looking down at many inflatable boats',
#   'boy in green shirt watches kayakers',
#   'boy looks over railing at the many boats and rafts below in the water',
#   'young boy overlooking crowd of inflatable boats',
#   'young boy wearing jersey looks down over ledge at many boats in the water'],
#  '1042590306_95dea0916c.jpg': ['man and woman pose for the camera while another man looks on',
#   'man is holding the hand of woman up to his mouth in front of some buildings while another man looks on',
#   'multiracial couple posing for picture',
#   'guy in blue shirt biting hand of girl in black striped jacket while another guy watches'],
#  '1045521051_108ebc19be.jpg': ['person eats takeout while watching small television',
#   'person sits on the floor and eats in front of television',
#   'television with picture of girl on it',
#   'young man sits on the floor by the television with fast food meal in front of him',
#   'someone is laying in front of the tv eating food'],
#  '1048710776_bb5b0a5c7c.jpg': ['couple of several people sitting on ledge overlooking the beach',
#   'group of people sit on wall at the beach',
#   'group of teens sit on wall by beach',
#   'crowd of people at the beach',
#   'several young people sitting on rail above crowded beach'],
#  '1052358063_eae6744153.jpg': ['boy takes jump on his skateboard while another boy with skateboard watches',
#   'child is performing skateboard trick while another child with skateboard leans on wall',
#   'little boy skateboarder is doing trick on his board while another young skateboarder watches',
#   'young boy skateboarder jumping on platform on skateboard',
#   'two skateboarders'],
#  '105342180_4d4a40b47f.jpg': ['woman kayaking down river',
#   'woman paddles boat down river',
#   'woman with paddle',
#   'woman with paddle sits in boat on the water'],
#  '1053804096_ad278b25f1.jpg': ['girl in pigtails splashes in the shallow water',
#   'girls plays in the surf',
#   'girl with pigtails is playing in the ocean by the beach',
#   'girl with pigtails plays in the water',
#   'young girl in pigtails plays in the water'],
#  '1055623002_8195a43714.jpg': ['group of four children wearing pajamas have pillow fight',
#   'group of kids have pillowfight',
#   'group of young children playing pillow fight on bed',
#   'children having pillow fight',
#   'four children are having pillow fight'],
#  '1055753357_4fa3d8d693.jpg': ['two constructions workers sit on beam taking break',
#   'two construction workers are sitting up on the side of building',
#   'two construction workers sitting on an ibeam',
#   'two construction workers take seat on steel beam',
#   'two men take break from construction'],
#  '1056249424_ef2a2e041c.jpg': ['the children are playing in the water',
#   'two boys play in puddle',
#   'two children play with balloon in mud on sunny day',
#   'two kids are running and playing in some water'],
#  '1056338697_4f7d7ce270.jpg': ['blond woman in blue shirt appears to wait for ride',
#   'blond woman is on the street hailing taxi',
#   'woman with blonde hair wearing blue tube top is waving on the side of the street',
#   'the woman in the blue dress is holding out her arm at oncoming traffic'],
#  '1056359656_662cee0814.jpg': ['little girl looking at brochure on train rides',
#   'young blond girl with magizine in her hands',
#   'young girl on train reads book about train rides',
#   'young girl sits on seat and looks at train pamphlet',
#   'child sitting down looking at train ride brochure'],
#  '1056873310_49c665eb22.jpg': ['brown dog is running after black dog on rocky shore',
#   'brown dog is running after the black dog',
#   'two dogs playing on beach',
#   'two dogs run across stones near body of water',
#   'two dogs run towards each other on rocky area with water in the background'],
#  '1057089366_ca83da0877.jpg': ['boy descends off the end of high diving board',
#   'child jumps off high diving board into the pool',
#   'kid jumps off the diving board and into the swimming pool below',
#   'little kid is jumping off high dive at the pool',
#   'the boy is jumping off high diving board into the pool'],
#  '1057210460_09c6f4c6c1.jpg': ['guy stands by window taking his overshirt off',
#   'man in tank top stands next to chrome door',
#   'man puts his shirt on near an elevator',
#   'man stands by an elevator with his head down',
#   'the man is putting on his shirt near an elevator'],
#  '1057251835_6ded4ada9c.jpg': ['lightcolored dog runs on the beach',
#   'small yellow dog runs on beach',
#   'tan dog runs on sandy beach',
#   'white dog is running down rocky beach',
#   'light brown dog running along the beach'],
#  '106490881_5a2dd9b7bd.jpg': ['boy in his blue swim shorts at the beach',
#   'boy smiles for the camera at beach',
#   'young boy in swimming trunks is walking with his arms outstretched on the beach',
#   'children playing on the beach',
#   'the boy is playing on the shore of an ocean'],
#  '106514190_bae200f463.jpg': ['hiker standing high on bluff overlooking the mountains below',
#   'person on ski looks from hill over snow covered landscape',
#   'skier is overlooking snowcovered mountain',
#   'skier is overlooking the beautiful white snow covered landscape',
#   'skier pauses on mountaintop'],
#  '1067180831_a59dc64344.jpg': ['black and white dog is attempting to catch yellow and purple object in low cut yard',
#   'black and white dog jumps after yellow toy',
#   'black and white dog jumps to get the frisbee',
#   'black dog is jumping up to catch purple and green toy',
#   'dog jumps to catch toy'],
#  '1067675215_7336a694d6.jpg': ['man in blue shorts is laying in the street',
#   'man in blue shorts lays down outside in parking lot',
#   'man laying down in middle of street during heavy traffic',
#   'man lies on mat in parking lot between brown suv and yellow pickup with an open door',
#   'shirtless man is laying down in the middle of busy street'],
#  '1067790824_f3cc97239b.jpg': ['white and black dog and brown dog in sandy terrain',
#   'woolly dog chases doberman on beach',
#   'one dog is chasing another one on the beach',
#   'the two large dogs are running through sand',
#   'two large dogs chasing each other at the beach'],
#  '1072153132_53d2bb1b60.jpg': ['black and white dog catches toy in midair',
#   'dog and tennis ball',
#   'dog leaps while chasing tennis ball through grassy field',
#   'multicolor dog jumping to catch tennis ball in grassy field'],
#  '107318069_e9f2ef32de.jpg': ['crowd watching air balloons at night',
#   'group of hot air balloons lit up at night',
#   'people are watching hot air balloons in the park',
#   'people watching hot air balloons',
#   'seven large balloons are lined up at nighttime near crowd'],
#  '1075716537_62105738b4.jpg': ['child with helmet on his head rides bike',
#   'little boy rides bike down hill on miniature dirt bike',
#   'young boy in helmet rides bike on the road',
#   'the little boy rides his bicycle in race',
#   'the young boy pedals quickly at bmx race'],
#  '107582366_d86f2d3347.jpg': ['group of eight people are gathered around table at night',
#   'group of people gathered around in the dark',
#   'group of people sit around table outside on porch at night',
#   'group of people sit outdoors together at night',
#   'group of people sitting at table in darkened room'],
#  '1075867198_27ca2e7efe.jpg': ['man in brown shirt and dark shorts plays on the beach with his two black dogs',
#   'man in shorts with two black dogs holds ball throwing toy at the beach',
#   'man playing with two black dogs on the beach',
#   'man with two dogs on beach',
#   'man at the beach with two dogs'],
#  '1075881101_d55c46bece.jpg': ['boy cleans the bubbles off his face',
#   'boy covered in suds has his face wiped clean',
#   'boy is covered in bubbles',
#   'child covered in foam is climbing on black inflatable ramp',
#   'person covered in soapy water is getting cleaned off'],
#  '1077546505_a4f6c4daa9.jpg': ['boy in blue shorts slides down slide into pool',
#   'boy in blue swimming trunks slides down yellow slide into wading pool with inflatable toys floating in the water',
#   'boy rides down slide into small backyard pool',
#   'boy sliding down slide into pool with colorful tubes',
#   'child is falling off slide onto colored balloons floating on pool of water'],
#  '1077931201_1e0bb83105.jpg': ['man in wetsuit is throwing baby wearing wetsuit up into the air',
#   'man in wetsuit is throwing toddler up in the air and is ready to catch him',
#   'man in water throwing little boy up in the air and waiting for him to come down so he can catch him',
#   'the man is in the pool and throwing small boy into the air'],
#  '1079274291_9aaf896cc1.jpg': ['little boy sticks his tongue out for the camera another boy looks on',
#   'two boys make faces',
#   'two young boys look up at the camera as one sticks out his tongue',
#   'two young boys making silly faces'],
#  '10815824_2997e03d76.jpg': ['blonde horse and blonde girl in black sweatshirt are staring at fire in barrel',
#   'girl and her horse stand by fire',
#   'girl holding horse lead behind fire',
#   'two people and two horses watching fire'],
#  '1082252566_8c79beef93.jpg': ['large brown dog is pushing small boston terrier with his face while anouther dog watches',
#   'large skinny dog stands near two smaller dogs int the dirt',
#   'there are three dogs starring at ball in the middle of them',
#   'three dogs of various sizes'],
#  '1082379191_ec1e53f996.jpg': ['lady and man with no shirt sit on dock',
#   'man and woman are sitting on dock together',
#   'man and woman sitting on dock',
#   'man and woman sitting on deck next to lake',
#   'shirtless man and woman sitting on dock'],
#  '1084040636_97d9633581.jpg': ['closeup of white dog that is laying its head on its paws',
#   'large white dog lying on the floor',
#   'white dog has its head on the ground',
#   'white dog is resting its head on tiled floor with its eyes open',
#   'white dog rests its head on the patio bricks'],
#  '1084104085_3b06223afe.jpg': ['woman in yellow shirt and green shorts is climbing an artificial red wall whilst wearing safety harness',
#   'woman in blue shorts and white shirt is indoor rock climbing',
#   'the girl is climbing rock wall',
#   'woman climbing an artificial rock wall'],
#  '1087168168_70280d024a.jpg': ['boy is jumping on an inflatable ring and girl is watching him',
#   'boy jumping on water jumphouse',
#   'teenage boy is jumping on an inflatable slide',
#   'young boy jumping and young girl seating in an inflatable pool',
#   'two young kids are playing in the water on an inflated toy'],
#  '1087539207_9f77ab3aaf.jpg': ['family playing on tractor on beautiful day',
#   'children ride tractor in field',
#   'several children playing on polaris vehicle outdoors',
#   'the children played on the four wheeler in the field',
#   'the four kids are riding on an atv in field'],
#  '1088767354_2acee738cf.jpg': ['woman in red costume to the left of man and woman standing together',
#   'woman wearing red costume looks at two other people standing on street',
#   'young woman in red sequined costume and feather stands on the sidewalk',
#   'the girl in the salmon colored bikini is standing next to two young people one is wearing black outfit and the other is drinking pop',
#   'two young people are approached by flamboyant young woman dressed in red bikini and red feathered headress'],
#  '108898978_7713be88fc.jpg': ['skiiers walking up the hill through forest',
#   'two men are skiing in the snow in wooded area',
#   'two people wearing yellow jackets crosscountry skiing',
#   'two skiers are making their way through woodland',
#   'two skiers are sliding down trail in the woods'],
#  '108899015_bf36131a57.jpg': ['lone skier is making their way up mountain',
#   'skiiers at the top of snow covered hill',
#   'two hikers climbing snowy hill',
#   'two people are on snowcovered mountain',
#   'two people climbing up snowy mountain'],
#  '1089181217_ee1167f7af.jpg': ['brown dog running down paved pathway',
#   'brown dog running next to grass',
#   'dog is running down road',
#   'light brown dog runs down path happily',
#   'energetic brown dog running'],
#  '1089755335_0bfbfd30e6.jpg': ['mother and children is fishing on boardwalk at night',
#   'woman and three children stand on deck with fishing pole',
#   'woman stands with children on boardwalk at night overlooking the sea',
#   'some people on pier at night with one girl fishing off it',
#   'woman with three children fishing over boardwalk in the evening'],
#  '109202756_b97fcdc62c.jpg': ['woman dressed in blue jacket and blue jeans rides brown horse near frozen lake and snowcovered mountain',
#   'woman in blue jacket rides brown pony near water',
#   'woman rides horse near frozen lake in the wintertime',
#   'young blond woman sitting atop brown draft horse in the snowy mountains',
#   'woman blue jacket sits on daft horse near frozen lake'],
#  '109202801_c6381eef15.jpg': ['two draft horses pull cart through the snow',
#   'two golden brown horses pull sleigh driven by woman in blue coat',
#   'two horses are pulling woman in cart',
#   'two horses pull carriage driven by woman over snow covered ground',
#   'two horses pulling sled steered by smiling blond woman'],
#  '109260216_85b0be5378.jpg': ['person climbing down sheer rock cliff using rope',
#   'person is climbing rock while holding onto white rope',
#   'person rappels down steep incline',
#   'person wearing red vest climbs up steep rock'],
#  '109260218_fca831f933.jpg': ['people stand inside rock dome',
#   'shaft of light in cave shows three spelunkers',
#   'spelunkers pose inside rock cavern while bathed in sunlight from the surface',
#   'three people sit in cave',
#   'three rock climbers are posing on big rocks'],
#  '1093716555_801aacef79.jpg': ['group of backpackers lay on the dry ground',
#   'group of hikers are resting on the ground in front of some mountains',
#   'people camp with the mountains in the background',
#   'several hikers rest with their gear in front of mountain',
#   'the group of hikers is resting in front of mountain'],
#  '1093737381_b313cd49ff.jpg': ['woman in blue dress stands with chalk portrait of two children playing by stream',
#   'woman standing in front of chalk drawing',
#   'woman stands next to chalk drawing in front of barnlike structure',
#   'woman stands outside near an elaborate chalk illustration',
#   'woman wearing blue dress is drawing picture of boy and girl on the sidewalk with sidewalk chalk'],
#  '1094462889_f9966dafa6.jpg': ['brown dog plays in deep pile of snow',
#   'dog looking at the camera in snow',
#   'dog runs through the snow',
#   'tan dog stand in the snow and looks up',
#   'the brown dog is out in the snow'],
#  '1095476286_87d4f8664e.jpg': ['boy jumping in fountain',
#   'boy plays in the fountains',
#   'child plays in fountain',
#   'little boy playing in the water',
#   'young boy is jumping through water being sprayed up from the ground'],
#  '1095580424_76f0aa8a3e.jpg': ['corgi runs out of tunnel',
#   'dog runs out of tunnel on course',
#   'dog running out of tunnel on obstacle course',
#   'the dog is running out of the tunnel on dog obedience course',
#   'the small brown and white dog is running out of small tunnel'],
#  '1095590286_c654f7e5a9.jpg': ['blond dog and black and white dog run in dirt field',
#   'dog chases another dog',
#   'yellow dog and black and white dog are running in the dirt',
#   'two dogs are running in field',
#   'two dogs running around'],
#  '1095980313_3c94799968.jpg': ['little girl in blue swimsuit is walking along wooden fence next to sandy beach',
#   'little girl with arms outstretched is posing at the beach',
#   'young girl walks on railing in front of the beach',
#   'little girl in blue swimsuit standing on handrail near beach',
#   'the little girl in the blue bathing suit is posing at the beach'],
#  '1096097967_ac305887b4.jpg': ['black and white dog drinking water from water spray',
#   'black and white dog is being soaked with jet of water in blue paddling pool',
#   'dog sticking its face into the shower from garden hose',
#   'small white dog gets sprayed by water',
#   'white and black dog is jumping into pool'],
#  '1096165011_cc5eb16aa6.jpg': ['boy smiles underwater',
#   'redheaded boy swimming underwater',
#   'small boy swimming underwater',
#   'smiling boy swims underwater in pool',
#   'the boys smiles underwater at the pool'],
#  '1096395242_fc69f0ae5a.jpg': ['boy with toy gun',
#   'little boy in orange shorts playing with toy',
#   'young boy with his foot outstretched aims toy at the camera in front of fireplace',
#   'young child plays with his new lightup toy',
#   'boy with toy gun pointed at the camera'],
#  '109671650_f7bbc297fa.jpg': ['boy in yellow shorts is standing on top of cliff',
#   'boy wearing blue and yellow walking on cliff edge',
#   'little boy standing high in the air on rock',
#   'young child is standing alone on some jagged rocks',
#   'child stands near edge of cliff'],
#  '109738763_90541ef30d.jpg': ['person on snowmobile in mid jump',
#   'snowmobiler flies through the air',
#   'snowmobile rider flies through the air on his or her machine in front of tall pine trees',
#   'rider jumps snowmobile high in rural area',
#   'the man is up in the air'],
#  '109738916_236dc456ac.jpg': ['people are riding around on snowmobiles',
#   'people pose with helmets and goggles on while riding snowmobiles',
#   'several people are taking break while on snowmobiling ride',
#   'three people and two snowmobiles',
#   'two helmeted men sit on yellow snowmobiles while another man stands behind watching'],
#  '109823394_83fcb735e1.jpg': ['three people drive atvs',
#   'three people on atvs in brown field turn their heads to look at the camera',
#   'three people on atv outside',
#   'three people on four wheel atv in field',
#   'three people ride their four wheelers through the field'],
#  '109823395_6fb423a90f.jpg': ['four wheeler jumping in an empty field',
#   'man on four wheeler is flying through the air',
#   'person is riding an orange atv in large empty field',
#   'man jumping with all terrain vehicle',
#   'man on an atv catching air'],
#  '109823397_e35154645f.jpg': ['man jumps gin the air while riding an atv',
#   'man on fourwheeler jumps near small building',
#   'an atv is airborne over field in front of white structure',
#   'person dressed in tan jacket jumps quad over harvested cornfield in front of small out building',
#   'man on four wheeler in the air'],
#  '1100214449_d10861e633.jpg': ['boy in striped shirt is jumping in front of water fountain',
#   'boy is jumping off the side of running stone water fountain in front of building',
#   'happy boy is jumping in front od city fountain',
#   'little boy is jumping in front of fountain',
#   'little boy is playfully jumping off the side of fountain'],
#  '1104133405_c04a00707f.jpg': ['boy carrying soccer ball',
#   'boy walks with ball tucked under his arm',
#   'boy walks with soccer ball near fence',
#   'boy wearing white tshirt walks on the grass and carries soccer ball',
#   'small boy carries soccer ball on field'],
#  '1105959054_9c3a738096.jpg': ['child painting picture',
#   'an artist paints clouds onto canvas',
#   'young girl painting picture',
#   'young girl with braids is painting with water colors on white paper on the wall',
#   'the child paints on large paper with water colors'],
#  '110595925_f3395c8bd6.jpg': ['cyclist is riding bicycle on curved road up hill',
#   'man in aerodynamic gear riding bicycle down road around sharp curve',
#   'man on mountain bike is pedaling up hill',
#   'the biker is riding around curve in the road'],
#  '1107246521_d16a476380.jpg': ['black dog jumping to catch rope toy',
#   'black dog playing fetch with ball of rope',
#   'black dog pounces to get rope toy',
#   'black dog running after his rope toy',
#   'large black dog is playing in grassy yard'],
#  '1107471216_4336c9b328.jpg': ['little girl is holding cine camera in front of her face',
#   'young girl is looking through an old fashioned video camera',
#   'young girl steadies her aim with camera',
#   'girl with rosy cheeks and lips holding black toy gun',
#   'there is kid with gun'],
#  '1110208841_5bb6806afe.jpg': ['black and white border collie catches frisbee in front of an audience',
#   'brown and white dog catches frisbee in it mouth in front of group of people',
#   'brown and white dug jumping up to catch frisbee while an audience watches',
#   'an agile dog catches frisbee while crowd of onlookers watches closely'],
#  '1112212364_0c48235fc2.jpg': ['baby is sitting on and playing with smooth rocks',
#   'baby is stacking rocks on the beach',
#   'small boy is playing with rocks',
#   'toddler sitting on pile of rocks holding rock at beach',
#   'toddler sits on pile of rocks'],
#  '111497985_38e9f88856.jpg': ['kid rock climbing against the backdrop of green valley',
#   'woman in striped shirt climbs up mountain',
#   'young man climbs rocky hill',
#   'the person has striped shirt on and is holding on to rope on mountain',
#   'the person in the striped shirt is mountain climbing'],
#  '111537217_082a4ba060.jpg': ['man climbing rock wall',
#   'man climbing the side of cliff',
#   'man is rock climbing',
#   'the young man with the white tshirt and jeans is rappeling up the rock wall'],
#  '111537222_07e56d5a30.jpg': ['climber wearing blue helmet and headlamp is attached to rope on the rock face',
#   'man climbs rocky wall',
#   'rock climber climbs large rock',
#   'woman in purple snakeskin pants climbs rock',
#   'person with blue helmet and purple pants is rock climbing'],
#  '1115565519_d976d4b1f1.jpg': ['child playing with fountain at the beach',
#   'child plays with fountain',
#   'girl looks at fountain that sprays water',
#   'little girl playing in water on frog sculpture',
#   'the little girl is playing with toy in public fountain'],
#  '1115679311_245eff2f4b.jpg': ['black dog is jumping over log along beach',
#   'black dog runs along the beach and jumps over wood barrior',
#   'dog is running on the beach',
#   'dog jumping over small wall at beach near the water',
#   'an animal is running on the beach'],
#  '111766423_4522d36e56.jpg': ['black and white bird eating seeds out of someone hand',
#   'black and white bird standing on hand',
#   'small bird sits in person hand and eats seeds',
#   'black and white bird standing on hand of someone holding sunflower seeds',
#   'the small bird is clinging to finger of the hand holding the seeds'],
#  '1117972841_2b9261f95f.jpg': ['brown dog is running in the sand',
#   'brown dog playing in the sand',
#   'brown dog plays at the beach',
#   'dog is standing in the sand',
#   'dog running fast in the sand'],
#  '1118557877_736f339752.jpg': ['little boy stands in the surf',
#   'small child wades through the water while being guided by another person',
#   'young boy laughs while splashing in the ocean',
#   'young boy wearing colorful bathing suit splashing in the ocean',
#   'young child splashing in water'],
#  '1119015538_e8e796281e.jpg': ['little tan dog with large ears running through the grass',
#   'playful dog is running through the grass',
#   'small dogs ears stick up as it runs in the grass',
#   'the small dog is running across the lawn',
#   'this is small beige dog running through grassy field'],
#  '1119418776_58e4b93eac.jpg': ['black and white dog is running through the field',
#   'dog running in field',
#   'dog with its mouth open running through field torwards the camera'],
#  '1119463452_69d4eecd08.jpg': ['girl in pink swimsuit in pool',
#   'girl swimming in pool',
#   'little girl in pink bathing suit swimming in pool',
#   'little girl swimming in pool',
#   'smiling little girl swimming in outdoor pool'],
#  '1121416483_c7902d0d49.jpg': ['child is standing on her head',
#   'little girl standing on her head',
#   'small child doing handstand on bed',
#   'young girl does handstand on bed with blue sheets',
#   'the girl is upside down on bed'],
#  '112178718_87270d9b4d.jpg': ['guy stands in the sand with snowboard behind him',
#   'man holds surfboard on the beach',
#   'man holds his snowboard in the sand',
#   'man with his surfboard stands in the sand',
#   'man is standing on white sand and holding snowboard'],
#  '112243673_fd68255217.jpg': ['people on atvs and dirt bikes are traveling along worn path in field surrounded by trees',
#   'three people are riding around on atv and motorcycles',
#   'three people on motorbikes follow trail through dry grass',
#   'three people on two dirtbikes and one fourwheeler are riding through brown grass',
#   'three people ride offroad bikes through field surrounded by trees'],
#  '1122944218_8eb3607403.jpg': ['baby in white garment holds flag with crescent moon and star',
#   'baby is holding small black flag with moon and star on it',
#   'baby wearing white gown waves muslim flag',
#   'little toddler dressed in white is smiling while lady helps him wave flag',
#   'baby in white outfit holding black and white flag'],
#  '1124448967_2221af8dc5.jpg': ['half naked man is sleeping on his chair outdoors',
#   'an older man sits back and relaxes on patio outside an adobe building where many bicycles are propped',
#   'man relaxing in folding chair on the street'],
#  '1129704496_4a61441f2c.jpg': ['brown and white and black and white dog hauling in floating toy from the ocean',
#   'both dogs retrieve the play toy from the water',
#   'two dogs in the ocean playing with toy',
#   'two dogs run through the water with rope in their mouths',
#   'two dogs tug at chew toy in the surf'],
#  '1130017585_1a219257ac.jpg': ['the young people party in the streets',
#   'three girls make faces as one takes drink while they stand in busy street',
#   'three women on the street drinking and posing',
#   'three young women pose for the camera at parade'],
#  '1130369873_d80a1aa59c.jpg': ['brown dog is running through neckdeep water carrying tennis ball',
#   'brown dog splashes in the water while carrying ball in its mouth',
#   'brown dog swims through water outdoors with tennis ball in its mouth'],
#  '1130401779_8c30182e3e.jpg': ['two brown dogs are creating large splashes as they run in river',
#   'two brown dogs in the water',
#   'two brown dogs running through water',
#   'two brown dogs runs through the water',
#   'two dogs splash through the water'],
#  '1131155939_b4b457b05e.jpg': ['black dog runs into the ocean next to pile of seaweed',
#   'dog is running in the waves at the beach'],
#  '1131340021_83f46b150a.jpg': ['young boy runs while wearing sandals',
#   'little boy in striped shirt and brown shorts is running',
#   'the little boy is wearing black pinstripe shirt and walking on deck',
#   'young boy running outside on the pavement'],
#  '1131800850_89c7ffd477.jpg': ['brown and white dog stands outside while it snows',
#   'dog is looking at something near the water',
#   'furry dog attempts to dry itself by shaking the water off its coat',
#   'white and brown dog shaking its self dry',
#   'the large brown and white dog shakes off water'],
#  '1131804997_177c3c0640.jpg': ['two men are sitting on the ground and going through their backpacks',
#   'two men sitting in front of railing are looking at something',
#   'two men with backpacks placed in front of them sitting in front of railing',
#   'two men with backpacks are sitting on cardboard along railing',
#   'two older men with backpacks sit at bus station'],
#  '1131932671_c8d17751b3.jpg': ['boy is jumping on bed',
#   'boy jumped up from the green bed',
#   'boy jumps from one bed to another',
#   'small child is jumping on bed',
#   'the boy in blue shorts is bouncing on the bed'],
#  '1132772170_600610c5df.jpg': ['child leaping from bed to bed behind the back of man',
#   'man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room',
#   'man wearing yellow shirt standing in the middle of two beds that boy is jumping on in the background',
#   'young child jumping on the bed as man looks the other way',
#   'man standing in the bedroom with little boy jumping into bed'],
#  '113678030_87a6a6e42e.jpg': ['snowboarder sits on slope with skiers and boarders nearby',
#   'snowboarder takes rest on the mountainside',
#   'snowboarders sitting in the snow while skiers take the hill',
#   'the snowboarder is sitting down'],
#  '1138784872_69ade3f2ab.jpg': ['girl in green walks down city street',
#   'small child in green clothing walks past store opening and woman in pink pants',
#   'small child walks down sidewalk',
#   'young boy is walking in front of some stores',
#   'the child in the green one piece suit is walking past store window'],
#  '114051287_dd85625a04.jpg': ['boy dressed in soccer attire and holding his shoes getting out of car',
#   'boy in red soccer strip is holding his boots in his hand whilst stepping out of car',
#   'boy in glasses is wearing red shirt',
#   'child getting out of the car wearing soccer shoes',
#   'young boy gets out of the van and prepares his shoes for wear during soccer game'],
#  '1141718391_24164bf1b1.jpg': ['man and woman are crossing over rope bridge with greenery all over them',
#   'man and woman are walking across rope bridge',
#   'man and woman crossing suspension bridge in tropical setting',
#   'woman and man walking across wooden rope bridge with caution sign beside it'],
#  '1141739219_2c47195e4c.jpg': ['family gathered at painted van',
#   'girl climbing down from the side of bright blue truck while others watch',
#   'man is helping girl step down from colorful truck whilst woman and three children watch',
#   'very colorful bus is pulled off to the side of the road as its passengers load',
#   'two women and four children standing next to brightly painted truck'],
#  '1142283988_6b227c5231.jpg': ['blond woman poses with person in pink costume',
#   'smiling woman holds person dressed in pig costume',
#   'young woman hugs young man who wearing pink costume',
#   'two people are hugging and one is wearing pinkhooded stretch top'],
#  '1142847777_2a0c1c2551.jpg': ['bicyclist riding on city street',
#   'woman in blue helmet and brown shorts rides her bike on busy street',
#   'woman is riding blue bike',
#   'woman is riding her bicycle in traffic',
#   'woman wearing blue helmet rides her bicycle in parking lot'],
#  '1143373711_2e90b7b799.jpg': ['bicycle rider is crossing street',
#   'bicyclist getting ready to cross street',
#   'biker in spandex riding on busy street',
#   'man in blue and white biking gear rides down busy street',
#   'man wearing helmet riding his bicycle down the street'],
#  '1143882946_1898d2eeb9.jpg': ['lady wearing helmet holding bike',
#   'woman in blue vest and sky blue helmet stands with her bicycle in traffic',
#   'woman in helmet rides her bike behind car',
#   'woman with helmet and backpack walks next to her bike',
#   'women with bike and helmet wait for traffic'],
#  '1144288288_e5c9558b6a.jpg': ['man in shorts is jogging along street with headset',
#   'person in blue shorts and wearing walkman jogs',
#   'woman in white shirt and blue shorts is wearing headphones',
#   'woman walks on street wearing headphones',
#   'woman wearing white hat and shirt is jogging down street with plant store on the corner'],
#  '1148238960_f8cacec2fc.jpg': ['bicyclists are standing at an intersection',
#   'bicyclists waiting at an intersection',
#   'people on bicycles waiting at an intersection',
#   'people waiting at light on bikes',
#   'three bikers stop in town'],
#  '1149179852_acad4d7300.jpg': ['man without shirt on is guiding large brown horse pulling green and yellow wagon',
#   'shirtless man escorts horse pulling carriage along paved road',
#   'shirtless man leading horse that is pulling carriage',
#   'shirtless man leading small horsedrawn covered wagon down road',
#   'the shirtless man is walking the shetland pony and carriage down the street'],
#  '114949897_490ca7eaec.jpg': ['boy hits ball off of tee ball into to net',
#   'man holds net while boys bats ball into it',
#   'the man is holding the net for the boy playing baseball',
#   'three people put up batting cage'],
#  '1151466868_3bc4d9580b.jpg': ['small girl spins in the waves in the bright sun',
#   'young girl plays in shallow water',
#   'young girl wears shirt and shorts as she plays in the ocean surf',
#   'girl running through the water near the shore',
#   'the little girl splashes through the water'],
#  '1153704539_542f7aa3a5.jpg': ['girl playing trumpet in marching band',
#   'teenager plays her trumpet on the field at game',
#   'young girl wearing blue shirt marching in band playing trumpet',
#   'girl playing the trumpet in marching band',
#   'girl wearing blue shirt and black shorts plays trumped outside'],
#  '1155138244_859fd6e079.jpg': ['girl hands out starbucks samples at street fair',
#   'an asian girl in green hat and apron is serving drinks on tray',
#   'starbucks barista offering up tray of drinks',
#   'the waitress offers complimentary tea to the patrons',
#   'woman dressed in green hat and apron is holding try full of drink samples'],
#  '115684808_cb01227802.jpg': ['three men are setting up sledge on snowy plain',
#   'three men loading items on sled',
#   'three people and sled',
#   'three people are standing in the snow preparing an ice fishing boat',
#   'three people in the snow put their gear in order'],
#  '1159574340_99ba8c3c59.jpg': ['child jumping into lake in wooded area while another child plays on the shore',
#   'child jumps into the water with his sneakers on',
#   'kid jumping into pool of water',
#   'little boy in sneakers jumping into water',
#   'the man takes leap into the water with his shoes on'],
#  '1160034462_16b38174fe.jpg': ['elderly man in straw hat is sitting on bench',
#   'elderly man sits alone on park bench',
#   'an old man in straw hat sits on park bench',
#   'the old man in the brown hat is sitting on the bench',
#   'white haired man in gray sweater and straw hat sitting on bench under tree'],
#  '1160441615_fe6b3c5277.jpg': ['three girls are walking across bridge covered with wood and surrounded by trees',
#   'three girls walking along an arched garden pathway',
#   'three girls walk under an arbor on path surrounded by trees',
#   'three women walking through tunnel in park',
#   'three women walk through plant covered atrium hallway'],
#  '1163282319_b729b24c46.jpg': ['little girl in red hat and yellow flip flops sits on rock',
#   'young girl wearing yellow flipflops is sitting on large boulder',
#   'the little girl sits on top of rock'],
#  '116409198_0fe0c94f3b.jpg': ['man eats near tent in the snow',
#   'man sitting near tent in the snow and ice',
#   'mountaineer sits in the snow in front of yellow tent under clear blue sky',
#   'person wearing hooded jacket sitting on snow in front of yellow tent',
#   'young man in hooded jacket sitting on snow in mountain area'],
#  '1164131282_b30926f332.jpg': ['grey dog beside black and white dog running in green grass',
#   'two dogs are wrestling in grassy field',
#   'two dogs run along grassy field while one bites the other',
#   'two dogs wrestle in field'],
#  '1164765687_7aca07bbe7.jpg': ['man in red shirt and glasses is bending down towards small dog on blanket with several stuffed animals',
#   'man in red shirt is giving toys to small dog',
#   'man is playing tug of war with his dog',
#   'man playing with black dog on white blanket',
#   'man playing with his dog on the blanket on the floor'],
#  '1167662968_e466f1e80a.jpg': ['guy with nose piercing',
#   'man in red cap with nose ring',
#   'teenage boy has silver ring protruding from his nose',
#   'closeup picture of man with nose ring and brown shirt',
#   'young man with nose ring and hat'],
#  '1167669558_87a8a467d6.jpg': ['man in yellow grimaces',
#   'man wearing yellow shirt with dramatic look on his face',
#   'the man in the yellow tshirt is pulling large grin on his face',
#   'this man is smiling very big at the camera'],
#  '1167908324_8caab45e15.jpg': ['man is standing by group of video games in bar',
#   'man standing in bar with neon beer sign hanging on the wall',
#   'man stands next to bank of computer gambling machines',
#   'man stands next to three video game machines and beer sign',
#   'man stands next to three video machines'],
#  '1169307342_e7a4685a5c.jpg': ['big brown dog plays with smaller grey dog on the grass',
#   'the dark brown dog is playing with the light brown dog',
#   'two brown dogs are running through the grass',
#   'two brown dogs run side by side',
#   'two dogs running and playing rough in the grass'],
#  '1174525839_7c1e6cfa86.jpg': ['girl in blue is jumping on the shore as small waves approach her',
#   'girl leaps into the air while standing by the ocean',
#   'the girl is running into the ocean from the shore',
#   'the girls is jumping into the air on the beach'],
#  '1174629344_a2e1a2bdbf.jpg': ['crowd of people walk down busy sidewalk',
#   'group of different people are walking in all different directions in city',
#   'group of people walking city street in warm weather',
#   'busy intersection in the summer time in city',
#   'people in summer clothes are walking on the sidewalk of large city'],
#  '1176580356_9810d877bf.jpg': ['big dog catches ball on his nose',
#   'brown and black dog is jumping to catch red ball',
#   'brown and black dog jumps for red ball',
#   'dog jumps to get orange ball on his head',
#   'the brown and black dog is jumping up to catch red ball'],
#  '1177994172_10d143cb8d.jpg': ['two boys are squirting water guns at each other',
#   'two boys spraying each other with water',
#   'two children wearing jeans squirt water at each other',
#   'two young boys are squirting water at each other'],
#  '1178705300_c224d9a4f1.jpg': ['brown dog jumping into pool after bloe ball',
#   'dog in the air above the swimming pool',
#   'dog jumps into backyard pool',
#   'tan colored dog is jumping into an outdoor pool',
#   'tan colored dog leaps into the inground pool'],
#  '118187095_d422383c81.jpg': ['parents are pushing little children in red car carts',
#   'twin boys being pushed in small car shaped strollers in parade',
#   'twin toddlers dressed alike being pushed in plastic car strollers in parade',
#   'two children ride in toy cars',
#   'two kids being pushed in car shaped strollers in parade'],
#  '118309463_a532b75be9.jpg': ['boys baseball team wear their uniforms',
#   'small boy smiles as he stands with others wearing the same black hats',
#   'children sporting their florida dolphin caps',
#   'the boys are all wearing the same baseball hats',
#   'three boys wearing florida marlins hats'],
#  '1184967930_9e29ce380d.jpg': ['brown dog running through the grass and flowers',
#   'dog in field',
#   'dog running in field of grass and flowers',
#   'dog running in shrubbery along stream',
#   'dog walks through field'],
#  '1187435567_18173c148b.jpg': ['small brown and black dog',
#   'small brown and black dog playing with toy',
# ...
#   'black dog is stepping on the ice',
#   'black dog plays with bit of ice by the frozen river',
#   'dog stands on the edge of an icy body of water'],
#  '2083434441_a93bc6306b.jpg': ['an elderly woman is riding bicycle in the city as yellow taxi is about to pass by',
#   'an elderly woman rides bicycle along city street',
#   'an older woman with blond hair rides bicycle down the street',
#   'woman in grey overcoat rides her bicycle along street'],
#  '2083778090_3aecaa11cc.jpg': ['man in the snow wearing furry hat and black jacket with red scarf',
#   'man wearing hat in snowstorm',
#   'man with goatee wears fur hat in the snow',
#   'man in furry hat stands in snow'],
#  '2084103826_ffd76b1e3e.jpg': ['black and white dog is jumping in the grass',
#   'black and white dog is running with muzzle',
#   'black and white dog wearing face mask runs through field',
#   'black and white dog with mask on its face is running in field',
#   'the black and white muzzled dog is leaping above the grass'],
#  '2084157130_f288e492e4.jpg': ['black and white dog runs beside brown dog in green field',
#   'the black and white dog along with the brown dog are galloping outside',
#   'two dogs race through field',
#   'two dogs run across the grassy field',
#   'two dogs running fast in the grass'],
#  '2084217208_7bd9bc85e5.jpg': ['woman is riding her bicycle',
#   'woman riding bike in park',
#   'woman with blue jacket wears helmet as she rides bike',
#   'woman with helmet riding bike'],
#  '2085078076_b9db242d21.jpg': ['small boy standing near muddy water with something in his hand while someone beside him washes clothing in buckets',
#   'young black child stands on the edge of body of water near buckets',
#   'young boy stands near the water in muddy river',
#   'child standing by rivers edge with laundry in buckets next to them'],
#  '2085255128_61224cc47f.jpg': ['boy high in the air above the dirt and water near the red rock cliffs',
#   'medium sized child jumps off of dusty bank over creek',
#   'young person wearing grey shirt and yellow shorts jumping into river',
#   'the boy in yellow shorts leaps from river bank towards the river'],
#  '2085400856_ae09df33a7.jpg': ['dog in the snow',
#   'dog laying in the snow',
#   'dog lays on the snow',
#   'golden dog plays in the snow',
#   'red dog crouches in the snow'],
#  '2085403342_a17b0654fe.jpg': ['child in bright red jacket runs through pile of hay',
#   'little girl in red sweater and blue skirt is in the hay',
#   'young child dances on straw surface',
#   'the boy is running through hay at pumpkin patch',
#   'the child is walking through straw'],
#  '2085557551_7a88d01d4e.jpg': ['boy holding kitchen utensils and making threatening face',
#   'boy is pulling wild face whilst waving cooking implements in his hands',
#   'girl in tan shirt holding up fork and knife in one hand and pot in the other',
#   'person with cooking utilities poses menacingly in dark environment',
#   'woman with knife and fork grimmaces'],
#  '2085726719_a57a75dbe5.jpg': ['two girls bundled up in winter coats pose for picture',
#   'two girls holding drinks and looking at something on cellphone',
#   'two teen girls are looking at small electronic device while wearing winter coats',
#   'two women dressed for cold weather in jackets and gloves look at something on cellphone screen',
#   'two young girls huddle to look at cellphone'],
#  '2086513494_dbbcb583e7.jpg': ['girl in white coat takes pictures',
#   'girl in white puffy jacket takes picture',
#   'group of people looking into their cameras',
#   'asian woman in white coat takes photo',
#   'the woman in the white coat is holding camera in her hand'],
#  '2086532897_b8714f2237.jpg': ['kayaker falling down waterfall',
#   'man is kayaking down waterfall',
#   'man on kayak coming down raging waterfall',
#   'person is on small boat and going down some very strong water currents',
#   'white water rafter goes through rough spot'],
#  '2086534745_1e4ab80078.jpg': ['man in yellow boat paddling down rough waters',
#   'rafter in yellow raft in steamy white river',
#   'yellow kayak is descending quickly down white water rapid',
#   'kayacker riding rough current downstream',
#   'the yellow kayak is in the middle of the rapids'],
#  '2086678529_b3301c2d71.jpg': ['girl in purple dress smiling as she climbs an indoor rock wall',
#   'girl is in dress',
#   'little girl wearing purple dress looks down at the camera',
#   'young girl wears purple dress'],
#  '2087317114_cf06df5aa5.jpg': ['mani is kayaking down some calmer rapids',
#   'man in small kayak is floating down the river',
#   'man in yellow jacket is floating on the river in green kayak',
#   'man smiles in his blue and green kayak',
#   'man wearing helmet in pyranha kayak floats down some river rapids'],
#  '2087640654_1a84577a44.jpg': ['blonde dog is digging deep hole in the ground and its tail is up in the air',
#   'dog half way in hole in the ground',
#   'dog is digging large hole in yard to find something',
#   'dog is digging in the ground and half of his body is under the ground',
#   'the rear end of an animal whose front end is underground'],
#  '2088120475_d6318364f5.jpg': ['person dressed up as snowman is walking through crowd of people',
#   'people pose for picture in the snow',
#   'three young people pose by snowman in red tie',
#   'two couples pose with snowman'],
#  '2088460083_42ee8a595a.jpg': ['broken down hummer gets towed on truck bed',
#   'damaged vehicle is carried by repair truck in nighttime scene',
#   'flat bed truck in parking lot with an army vehicle on its bed',
#   'dirty suv sits on the bed of tow truck at night'],
#  '2088532947_c628e44c4a.jpg': ['the girl in the white shirt has bracelet on and has her arm around the girl in the peach shirt',
#   'the two girls laid on the grass together',
#   'two little girls are laying on the grass smiling',
#   'two young girls holding each other on the grassy ground',
#   'two young girls hug each other in the grass'],
#  '2088910854_c6f8d4f5f9.jpg': ['large man is wearing headband with mistletoe attached to it',
#   'man in sweatshirt and cap wears flower on his head',
#   'man wearing black knit cap with red and white striped headband with flower on top',
#   'an man with black ski cap and red and white headband looks into the distance',
#   'man wearing black hat with christmas theme'],
#  '2089122314_40d5739aef.jpg': ['dog running with newspaper in its mouth',
#   'dog with newspaper in his mouth runs down paved path',
#   'an australian shepherd dog carrying newspaper in his mouth'],
#  '2089350172_dc2cf9fcf6.jpg': ['three black dogs swimming in dirty water',
#   'three dark dogs swimming and one of them has ball',
#   'three dogs are up to their necks in water',
#   'three dogs swim in the water'],
#  '2089426086_7acc98a3a8.jpg': ['girl in hooded jacket presents cake with candles',
#   'girl in hood jacket holds birthday cake with many candles',
#   'girl in winter coat with birthday cake',
#   'girl is holding birthday cake',
#   'young girl holding cake with candles dressed in heavy coat'],
#  '2089442007_6fc798548c.jpg': ['brown dog is walking in the water',
#   'brown dog takes cautious steps in the calm waters with sandy bottom',
#   'brown dog wades in the water',
#   'dog with red fur stands in body of water'],
#  '2089539651_9e518ec7de.jpg': ['hiker with two hiking poles stands on hillside with view of the city below him',
#   'hiker with two sticks is standing on path that is high up on hill',
#   'hiking man stands on cliff overlooking city',
#   'man hikes on dirt path high above city',
#   'person holding poles is standing on rock ledge with bushes on each side overlooking mountains'],
#  '2089542487_b4c1ee7025.jpg': ['hiker is ready to take on rugged outdoor trail',
#   'lone hiker on dirt hiking trail with hat and sunglasses on with trees in the background',
#   'man in shorts is hiking in dry region',
#   'man stops for picture with the scenery during his hike'],
#  '2089555297_95cf001fa7.jpg': ['man in hat with long sleeves and long pants stands overlooking city',
#   'man stands on cliff overlooking city',
#   'man with backpack and hat is standing by high cliff where you can see for miles',
#   'hiker standing on top of rock overlooking town'],
#  '2090327868_9f99e2740d.jpg': ['woman and two small children posing in front of large cow statue',
#   'woman gives baby to small child to hold as they stand in front of cow statue',
#   'woman stands with two children near decorated bull statue',
#   'the woman and children are standing next to statue of cow'],
#  '2090339522_d30d2436f9.jpg': ['man in green hat is someplace up high',
#   'man in green hat is taking self portrait',
#   'man in hat at scenic overlook',
#   'man wearing green canvas hat with distnat city in the background',
#   'man with green hate and sunglasses on high up peak'],
#  '2090386465_b6ebb7df2c.jpg': ['woman and man in winter gear stand',
#   'three adults wearing cold weather gear',
#   'two people are wearing heavy clothing',
#   'two people in winter clothing',
#   'two women bundled up on snowy day'],
#  '2090387793_274ab4cf7d.jpg': ['boy wearing black walks down the street with his hands in fists',
#   'teenage boy dressed in black stands on snowy street',
#   'teenage boy wearing all black tries to look tough with cheap jewelry on',
#   'young man wearing black hat and jacket is walking outside',
#   'punk rock teenager walks with mean look on his face'],
#  '2090545563_a4e66ec76b.jpg': ['the boy laying face down on skateboard is being pushed along the ground by another boy',
#   'two girls play on skateboard in courtyard',
#   'two people play on long skateboard',
#   'two small children in red shirts playing on skateboard',
#   'two young children on skateboard going across sidewalk'],
#  '2090723611_318031cfa5.jpg': ['dogs walking in the grassy field',
#   'large fluffy grey dog standing in grass in front of brown dog',
#   'one dog standing in some grass with his tongue hanging out and tan dog in the background',
#   'two dogs of different breeds are standing in pasture',
#   'two dogs stand in the grass'],
#  '2090997177_76d482b158.jpg': ['black dog bounds across the sand',
#   'dog walking across the desert',
#   'short black dog is walking over barren landscape',
#   'small black dog running across the sand',
#   'small black dog walks in the sand'],
#  '2091171488_c8512fec76.jpg': ['female wearing pink gloves and brown jacket is smiling in the snow',
#   'woman standing in the snow with people in the background',
#   'young woman in spring coat and purple gloves stands in falling snow',
#   'young woman looks happy in winter clothes while it snows',
#   'young asian woman with pink gloves stands in the snow'],
#  '2092177624_13ab757e8b.jpg': ['boy in african clothing runs across concrete wall',
#   'little boy with green shirt is running on rock ledge',
#   'an african boy in large green shirt is running barefoot along wall',
#   'boy in green tunic on rock wall'],
#  '2092419948_eea8001d0f.jpg': ['long haired man walking away beside canal whist holding onto railing',
#   'man walks down path next to waterway',
#   'person walks by some bluegreen water while holding rail',
#   'person with long ponytail walks along waterway under tunnel',
#   'the man with long hair is walking along storm drain'],
#  '2092870249_90e3f1855b.jpg': ['man lies on street with his head and shoulders under parked car that is jacked up',
#   'man looks under car on wet street',
#   'man works on car',
#   'person underneath car with jack'],
#  '2094323311_27d58b1513.jpg': ['dog places his head on man face',
#   'dog snuggles with man in sunglasses',
#   'dog with blue collar is licking man who wearing large tinted sunglasses',
#   'large brown dog with blue collar is resting his chin on man face',
#   'an orange dog is licking man wearing red sunglasses'],
#  '2094543127_46d2f1fedf.jpg': ['girl holding crocodile mouth closed',
#   'girl is posed over statue of dangerous animal',
#   'girl sits on what appears to be crocodile',
#   'girl sitting on top of crocodile',
#   'girl with red hair is sitting on crocodile holding its jaw'],
#  '2094810449_f8df9dcdf7.jpg': ['boy stands in the ocean lifting up his shorts',
#   'child in blue shorts is standing ankle deep in the water',
#   'the kid is wearing blue jacket and standing in shallow beach water',
#   'the small child wades ankle deep in the water on the shoreline'],
#  '2095007523_591f255708.jpg': ['baby looks through his crib',
#   'baby in playpen with wide eyes',
#   'baby looking through playpen bars at camera'],
#  '2095078658_c14ba89bc2.jpg': ['dog runs through snow in front of the woods',
#   'large dog running in snow',
#   'the dog runs through the snow',
#   'the german shepherd dog is running through the snow',
#   'the german shepherd is running through the white snow'],
#  '2095435987_1b7591d214.jpg': ['dog lying on its back in the sand',
#   'white and brown dog rolls on its back in the sand',
#   'the dog rolls over to scratch its back in the sand',
#   'the white and brown dog is rolling in the sand',
#   'the white dog is on its back in the sand with paws in the air'],
#  '2095444126_201ff9f222.jpg': ['dog is shaking off water',
#   'dog shakes his head',
#   'dog shakes off water',
#   'dog shakes off water and gets contorted',
#   'the dog is shaking water off of his body'],
#  '2095478050_736c4d2d28.jpg': ['man and boy play music as little girls watch',
#   'man is playing guitar with child playing harmonica while three young girls watch',
#   'three children watch man onstage playing guitar',
#   'three little girls look on as boy plays the harmonica with an adult guiutarist sitting beside him',
#   'three little girls watch band'],
#  '209605542_ca9cc52e7b.jpg': ['climber wearing red headband is pulling himself up some grey rocks high above some green foliage',
#   'man in headband climbing rock',
#   'man with red headband climbing rock cliff looming over greenery',
#   'man climbing sheet rock face',
#   'man in red headband climbing rock'],
#  '2096771662_984441d20d.jpg': ['man looks through his binoculars while another man holds drink',
#   'man with thermos is standing next to man who is gazing through binoculars',
#   'two men are standing together while one looks through binoculars',
#   'two men look out as one is holding binoculars',
#   'two people standing next to each other with mountains in the distance'],
#  '2097398349_ff178b3f1b.jpg': ['hiker waves to the camera as he standing in front of snowcapped mountains',
#   'man stands on the snow near the mountains',
#   'person poses in the snow',
#   'skier in the mountains'],
#  '2097403787_77a154f5b9.jpg': ['lone person standing on some rocks with large snowy mountains in the background',
#   'man is standing on the rocky ground in front of the mountain',
#   'man standing in front of an icy mountain',
#   'the person is standing by the water in front of the snow topped mountains',
#   'the traveller pauses in front of the mountain view'],
#  '2097407245_c798e0dcaf.jpg': ['man in winter jacket and knit cap stand with his arms up at his side in snow landscape',
#   'man is standing on dirt with his hands in the air with mountains and snow behind him',
#   'man raises his arms on rocky beach',
#   'one lone man with fist in the air with large rocky mountains in the background',
#   'man with outstretched arms standing on snowcovered rocks'],
#  '2097420505_439f63c863.jpg': ['male hiker wearing green jacket is posing next to large glacier',
#   'man with camera and an ice structure behind him',
#   'man with camera crouching on ice',
#   'man with camera kneels in front of giant hill of snow',
#   'the mountain climber prepares to take photo'],
#  '2097489021_ca1b9f5c3b.jpg': ['girl in ballet fairy costume is touched by wand',
#   'young girl performing the nutcracker',
#   'the little girl is standing on stage dressed up as pink fairy',
#   'young girl waving turquiose leotard and pink tutu with wings waving wand'],
#  '2098174172_e57d86ea03.jpg': ['hiker is posing in front of snowy mountains',
#   'hiker is standing in before the mountain holding two walking sticks',
#   'man stands in front of snow covered mountains',
#   'man with two ski poles stands near mountaintop',
#   'the man wears green hat and jacket while standing in front of mountain'],
#  ...}

# %%
image_features_directory = '/content/drive/MyDrive/Images'
image_features = load_image_features(image_features_directory)
image_features
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 [==============================] - 3s 0us/step
# 100%|██████████| 8089/8089 [15:37<00:00,  8.63it/s]
# {'1926129518_4350f4f552': array([[0.21642402, 0.6197052 , 0.07396493, ..., 0.12976904, 0.7567191 ,
#          0.28012124]], dtype=float32),
#  '1924234308_c9ddcf206d': array([[0.25118873, 0.06160817, 1.0082335 , ..., 0.07204767, 0.9761707 ,
#          0.78691566]], dtype=float32),
#  '1925434818_2949a8f6d8': array([[0.4691009 , 0.15489951, 0.48743623, ..., 0.35811326, 0.44115573,
#          0.9695739 ]], dtype=float32),
#  '1928319708_ccf1f4ee72': array([[0.08152099, 0.3943622 , 0.059411  , ..., 0.17081073, 0.73480487,
#          0.9359209 ]], dtype=float32),
#  '1931690777_897a7d8ab6': array([[0.86859936, 1.0595572 , 0.6533682 , ..., 0.7826594 , 0.80521756,
#  '453473508_682c0a7189': array([[0.23868275, 0.09772699, 0.11661578, ..., 0.3581637 , 0.31017494,
#          0.10504158]], dtype=float32),
#  '453756106_711c20471a': array([[0.08301682, 0.34576762, 0.07548238, ..., 0.4806839 , 0.09571235,
#          0.01389829]], dtype=float32),
#  '454686980_7517fe0c2e': array([[0.25864652, 0.4897817 , 0.3477675 , ..., 0.05110597, 0.3437613 ,
#          0.24881554]], dtype=float32),
#  '454691853_cc1e0fa6a1': array([[0.23724422, 0.391148  , 0.39887404, ..., 0.4589389 , 0.9232453 ,
#          0.25149763]], dtype=float32),
#  '454709143_9c513f095c': array([[0.2152603 , 0.09160874, 0.5250124 , ..., 0.02924513, 0.43884844,
#          0.40799087]], dtype=float32),
#  '455611732_d65bf3e976': array([[0.22975682, 0.47631654, 0.22120813, ..., 0.13612252, 0.5934641 ,
#          0.6299566 ]], dtype=float32),
#  '455856615_f6361d9253': array([[0.17460169, 0.6128254 , 0.07264644, ..., 0.2671063 , 0.0786364 ,
#          0.9799503 ]], dtype=float32),
#  '456299217_b2802efbc2': array([[0.06438379, 0.5320958 , 0.78692555, ..., 1.5788119 , 0.06831563,
#          0.93940604]], dtype=float32),
#  '456512643_0aac2fa9ce': array([[0.08130483, 0.11462172, 0.12503302, ..., 0.24986419, 0.47973794,
#          0.5748475 ]], dtype=float32),
#  '457631171_12b1aee828': array([[0.06881092, 0.12083317, 0.11787535, ..., 0.36055064, 0.3300768 ,
#          0.57506585]], dtype=float32),
#  '457875937_982588d918': array([[0.33773768, 0.1763829 , 0.3230276 , ..., 0.03057229, 0.20073475,
#          0.4568128 ]], dtype=float32),
#  '457945610_1a23b9ced0': array([[0.11162207, 0.09224923, 0.10034357, ..., 0.57831585, 0.49859512,
#          0.08757632]], dtype=float32),
#  '458004873_f084c47a88': array([[0.7198748 , 0.78392017, 0.43853545, ..., 0.31230193, 0.48774058,
#          0.0199281 ]], dtype=float32),
#  '458183774_afe65abf67': array([[0.38610923, 0.5610155 , 0.39409113, ..., 0.07622897, 0.3324215 ,
#          0.28913337]], dtype=float32),
#  '458213442_12c59e61a0': array([[0.21557999, 0.95355904, 0.03729592, ..., 0.08911259, 0.6795101 ,
#          1.1291821 ]], dtype=float32),
#  '458735196_176e7df6b3': array([[0.46209502, 0.37239087, 0.19421008, ..., 0.57720804, 0.01749994,
#          0.68855155]], dtype=float32),
#  '459284240_5a4167bf92': array([[0.14950362, 0.15524176, 0.8959711 , ..., 0.47671527, 1.3871732 ,
#          0.48146743]], dtype=float32),
#  '459778335_857d8ffebf': array([[0.43072796, 0.05667507, 0.6373105 , ..., 0.7056947 , 0.74608546,
#          0.6059851 ]], dtype=float32),
#  '459814265_d48ba48978': array([[0.2584054 , 0.24173316, 0.0627689 , ..., 0.4352203 , 0.3436838 ,
#          0.02522795]], dtype=float32),
#  '460195978_fc522a4979': array([[0.292775  , 0.23449293, 0.2062254 , ..., 0.02312223, 0.24001816,
#          0.35915184]], dtype=float32),
#  ...}

# %%
# Creating tokenizer and further preprocessing captions
tokenizer = create_tokenizer(captions)
vocab_size = len(tokenizer.word_index) + 1
max_length = max(len(caption.split()) for caption_list in captions.values() for caption in caption_list)

# %%
# Creating sequences for training the model
def create_sequences(tokenizer, captions, image_features, vocab_size, max_length):
    X1, X2, y = [], [], []
    for img_id, caption_list in captions.items():
        image_feature = image_features.get(img_id)
        if image_feature is not None:
            for caption in caption_list:
                seq = tokenizer.texts_to_sequences([caption])[0]
                for i in range(1, len(seq)):
                    in_seq, out_seq = seq[:i], seq[i]
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    X1.append(image_feature)
                    X2.append(in_seq)
                    y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

# %% [markdown]
# #Training the model

# %%
X1train, X2train, ytrain = create_sequences(tokenizer, captions, image_features, vocab_size, max_length)

# %%
# Defining the model
model = define_model(vocab_size, max_length)

# %%
def data_generator(X1, X2, y, vocab_size, max_length, batch_size):
    while True:
        for i in range(0, len(X1), batch_size):
            X1_batch = X1[i:i+batch_size]
            X2_batch = X2[i:i+batch_size]
            y_batch = y[i:i+batch_size]

            X2_batch = pad_sequences(X2_batch, maxlen=max_length)

            y_batch = [to_categorical([word], num_classes=vocab_size)[0] for word in y_batch]

            yield ([np.array(X1_batch), np.array(X2_batch)], np.array(y_batch))

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# Assuming you have already loaded X1train, X2train, ytrain, tokenizer, max_length, vocab_size

# Pad input sequences and one-hot encode output sequences
X2train_padded = pad_sequences(X2train, maxlen=max_length)
ytrain_encoded = to_categorical(ytrain, num_classes=vocab_size)

# Train the model
epochs = 15
batch_size = 64


history = model.fit(
    [np.array(X1train), X2train_padded],
    ytrain_encoded,
    epochs=epochs,
    batch_size=batch_size,
    verbose=1
)

# Save the model
model.save('image_captioning_model.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-683d49416ced> in <cell line: 7>()
#       5 train_generator = data_generator(X1train, X2train, ytrain, vocab_size, max_length, batch_size)
#       6
# ----> 7 model.fit(train_generator, epochs=epochs, steps_per_epoch=steps_per_epoch, verbose=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1680         ):
#    1681             # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1682             data_handler = data_adapter.get_data_handler(
#    1683                 x=x,
#    1684                 y=y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1676             return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1677         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1678     return DataHandler(*args, **kwargs)
#    1679
#    1680
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1283
#    1284         adapter_cls = select_data_adapter(x, y)
# -> 1285         self._adapter = adapter_cls(
#    1286             x,
#    1287             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     881         # Since we have to know the dtype of the python generator when we build
#     882         # the dataset, we have to look at a batch to infer the structure.
# --> 883         peek, x = self._peek_and_restore(x)
#     884         peek = self._standardize_batch(peek)
#     885         peek = _process_tensorlike(peek)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in _peek_and_restore(x)
#     947     @staticmethod
#     948     def _peek_and_restore(x):
# --> 949         peek = next(x)
#     950         return peek, itertools.chain([peek], x)
#     951
#
# <ipython-input-22-79e71be75b2a> in data_generator(X1, X2, y, vocab_size, max_length, batch_size)
#       1 def data_generator(X1, X2, y, vocab_size, max_length, batch_size):
#       2     while True:
# ----> 3         for i in range(0, len(X1), batch_size):
#       4             X1_batch = X1[i:i+batch_size]
#       5             X2_batch = X2[i:i+batch_size]
#
# KeyboardInterrupt:
